# %% [markdown]
# 测试数据和训练数据分组，数据分batch

# %%
import torch
from joblib import dump, load
import torch.utils.data as Data
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
# 参数与配置
torch.manual_seed(100)  # 设置随机种子，以使实验结果具有可重复性
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 有GPU先用GPU训练

# 加载数据集
def dataloader(batch_size, workers=2):
    # 训练集
    train_xdata = load('trainX_1024_10c')
    train_ylabel = load('trainY_1024_10c')
    # 验证集
    val_xdata = load('valX_1024_10c')
    val_ylabel = load('valY_1024_10c')
    # 测试集
    test_xdata = load('testX_1024_10c')
    test_ylabel = load('testY_1024_10c')

    # 加载数据
    train_loader = Data.DataLoader(dataset=Data.TensorDataset(train_xdata, train_ylabel),
                                   batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    val_loader = Data.DataLoader(dataset=Data.TensorDataset(val_xdata, val_ylabel),
                                 batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    test_loader = Data.DataLoader(dataset=Data.TensorDataset(test_xdata, test_ylabel),
                                  batch_size=batch_size, num_workers=workers, drop_last=True)
    return train_loader, val_loader, test_loader

batch_size = 32
# 加载数据
train_loader, val_loader, test_loader = dataloader(batch_size)

print(len(train_loader))
print(len(val_loader))
print(len(test_loader))
# Out:
# 50
# 14
# 7

# %%
import torch
from joblib import dump, load
import torch.utils.data as Data
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# 定义CNN-1D模型
class CNN1DModel(nn.Module):
    def __init__(self, conv_archs, num_classes, input_channels=1):
        super().__init__()
         # CNN参数
        self.conv_arch = conv_archs # 网络结构
        self.input_channels = input_channels # 输入通道数
        self.features = self.make_layers()
        # 平均池化
        self.avgpool = nn.AdaptiveAvgPool1d(1)
        # 线性层
        self.classifier = nn.Linear(conv_archs[-1][-1], num_classes)
        
    # CNN卷积池化结构
    def make_layers(self):
        layers = []
        for (num_convs, out_channels) in self.conv_arch:
            for _ in range(num_convs):
                layers.append(nn.Conv1d(self.input_channels, out_channels, kernel_size=3, padding=1))
                layers.append(nn.ReLU(inplace=True))
                self.input_channels = out_channels
            layers.append(nn.MaxPool1d(kernel_size=2, stride=2)) # 这里会使宽高减半
        return nn.Sequential(*layers)
    

    def forward(self,input_seq):  # torch.Size([32, 1024])
        batch_size = input_seq.size(0)
        seq_length = input_seq.size(1)

        #改变输入形状，适应网络输入[batch, dim, seq_length]
        input_seq = input_seq.view(batch_size , -1, seq_length)   # torch.Size([32, 1, 1024])
        features = self.features(input_seq)  # [32, 128, 128]
        # print(features.size())  # torch.Size([32, 128, 128])
        x = self.avgpool(features)          # ttorch.Size([32, 128, 1])
        # print(x.size())  # torch.Size([32, 128, 1])
        flat_tensor = x.view(batch_size, -1) # torch.Size([32, 128])
        output = self.classifier(flat_tensor)    # torch.Size([32, 10])
        return output

# %% [markdown]
# 输入数据的形状是
#  1. print(seq.size(), labels.size())
#  2. torch.Size([32, 1024])   torch.Size([32])

# %%
# 定义模型参数
# VGG11，VGG13，VGG16，VGG19 可自行更换。
#conv_arch = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))  # vgg11
#conv_arch = ((2, 64), (2, 128), (2 , 256), (2, 512), (2, 512))  # vgg13
#conv_arch = ((2, 64), (2, 128), (3, 256), (3, 512), (3, 512))  # vgg16
#conv_arch = ((2, 64), (2, 128), (4, 256), (4, 512), (4, 512))  # vgg19
# 先用浅层试一试
conv_arch = ((2, 32), (1, 64), (1, 128))  
input_channels = 1
num_classes = 10

model = CNN1DModel(conv_arch, num_classes, input_channels)  
# 定义损失函数和优化函数 
loss_function = nn.CrossEntropyLoss(reduction='sum')  # loss
loss_function = loss_function.to(device)
learn_rate = 0.0003
optimizer = torch.optim.Adam(model.parameters(), learn_rate)  # 优化器

# 看下这个网络结构总共有多少个参数
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')

count_parameters(model)
# Out:
#     96
#     32
#   3072
#     32
#   6144
#     64
#  24576
#    128
#   1280
#     10
# ______
#  35434

# %%
print(model)
# Out:
# CNN1DModel(
#   (features): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (3): ReLU(inplace=True)
#     (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (6): ReLU(inplace=True)
#     (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU(inplace=True)
#     (10): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool1d(output_size=1)
#   (classifier): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# 注意调整参数，
# 1. 可以适当增加 cnn层数 和每层神经元个数，微调学习率；
# 2. 增加更多的 epochs,  （注意防止过拟合）

# %%
# 训练模型
import time
import torch.nn.functional as F
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc("font", family='Microsoft YaHei')

def model_train(batch_size, epochs, train_loader, val_loader, model, optimizer, loss_function):
    model = model.to(device)
    # 样本长度
    train_size = len(train_loader) * batch_size
    val_size = len(val_loader) * batch_size

    # 最高准确率  最佳模型
    best_accuracy = 0.0
    best_model = model

    train_loss = []     # 记录在训练集上每个epoch的loss的变化情况
    train_acc = []    # 记录在训练集上每个epoch的准确率的变化情况
    validate_acc = []
    validate_loss = []

    # 计算模型运行时间
    start_time = time.time()
    for epoch in range(epochs):
        # 训练
        model.train()

        loss_epoch = 0.    #保存当前epoch的loss和
        correct_epoch = 0  #保存当前epoch的正确个数和
        for seq, labels in train_loader: 
            seq, labels = seq.to(device), labels.to(device)
            # print(seq.size(), labels.size()) torch.Size([32, 7, 1024]) torch.Size([32])
            # 每次更新参数前都梯度归零和初始化
            optimizer.zero_grad()
            # 前向传播
            y_pred = model(seq)  #   torch.Size([16, 10])
            # 对模型输出进行softmax操作，得到概率分布
            probabilities = F.softmax(y_pred, dim=1)
            # 得到预测的类别
            predicted_labels = torch.argmax(probabilities, dim=1)
            # 与真实标签进行比较，计算预测正确的样本数量  # 计算当前batch预测正确个数
            correct_epoch += (predicted_labels == labels).sum().item()
            # 损失计算
            loss = loss_function(y_pred, labels)
            loss_epoch += loss.item()
            # 反向传播和参数更新
            loss.backward()
            optimizer.step()
        #     break
        # break
        # 计算准确率
        train_Accuracy  = correct_epoch/train_size 
        train_loss.append(loss_epoch/train_size)
        train_acc.append(train_Accuracy)
        print(f'Epoch: {epoch+1:2} train_Loss: {loss_epoch/train_size:10.8f} train_Accuracy:{train_Accuracy:4.4f}')
        # 每一个epoch结束后，在验证集上验证实验结果。
        with torch.no_grad():
            loss_validate = 0.
            correct_validate = 0
            # 将模型设置为评估模式
            model.eval()
            for data, label in val_loader:
                data, label = data.to(device), label.to(device)
                pre = model(data)
                # 对模型输出进行softmax操作，得到概率分布
                probabilities = F.softmax(pre, dim=1)
                # 得到预测的类别
                predicted_labels = torch.argmax(probabilities, dim=1)
                # 与真实标签进行比较，计算预测正确的样本数量  # 计算当前batch预测正确个数
                correct_validate += (predicted_labels == label).sum().item()
                loss = loss_function(pre, label)
                loss_validate += loss.item()
            # print(f'validate_sum:{loss_validate},  validate_Acc:{correct_validate}')
            val_accuracy = correct_validate/val_size 
            print(f'Epoch: {epoch+1:2} val_Loss:{loss_validate/val_size:10.8f},  validate_Acc:{val_accuracy:4.4f}')
            validate_loss.append(loss_validate/val_size)
            validate_acc.append(val_accuracy)
            # 如果当前模型的准确率优于之前的最佳准确率，则更新最佳模型
            #保存当前最优模型参数
            if val_accuracy > best_accuracy:
                best_accuracy = val_accuracy
                best_model = model# 更新最佳模型的参数

    
    # 保存最后的参数
    # torch.save(model, 'final_model_cnn1d.pt')
    # 保存最好的参数
    torch.save(best_model, 'best_model_cnn1d.pt')
   
    print(f'\nDuration: {time.time() - start_time:.0f} seconds')
    plt.plot(range(epochs), train_loss, color = 'b',label = 'train_loss')
    plt.plot(range(epochs), train_acc, color = 'g',label = 'train_acc')
    plt.plot(range(epochs), validate_loss, color = 'y',label = 'validate_loss')
    plt.plot(range(epochs), validate_acc, color = 'r',label = 'validate_acc')
    plt.legend()
    plt.show()   #显示 lable 
    print("best_accuracy :", best_accuracy)



batch_size = 32
epochs = 100
# 模型训练
model_train(batch_size, epochs, train_loader, val_loader, model, optimizer, loss_function)
# Out:
# Epoch:  1 train_Loss: 2.27060864 train_Accuracy:0.1250
# Epoch:  1 val_Loss:2.20941448,  validate_Acc:0.0781
# Epoch:  2 train_Loss: 2.03944016 train_Accuracy:0.1100
# Epoch:  2 val_Loss:1.91922994,  validate_Acc:0.0960
# Epoch:  3 train_Loss: 1.72373456 train_Accuracy:0.3544
# Epoch:  3 val_Loss:1.53606649,  validate_Acc:0.5022
# Epoch:  4 train_Loss: 1.30871639 train_Accuracy:0.6000
# Epoch:  4 val_Loss:1.14793058,  validate_Acc:0.6607
# Epoch:  5 train_Loss: 0.98835672 train_Accuracy:0.6969
# Epoch:  5 val_Loss:0.90571238,  validate_Acc:0.7857
# Epoch:  6 train_Loss: 0.78609863 train_Accuracy:0.8006
# Epoch:  6 val_Loss:0.74116660,  validate_Acc:0.7790
# Epoch:  7 train_Loss: 0.67651841 train_Accuracy:0.8131
# Epoch:  7 val_Loss:0.65512509,  validate_Acc:0.7902
# Epoch:  8 train_Loss: 0.59257467 train_Accuracy:0.8556
# Epoch:  8 val_Loss:0.60972411,  validate_Acc:0.8304
# Epoch:  9 train_Loss: 0.55321077 train_Accuracy:0.8438
# Epoch:  9 val_Loss:0.55287807,  validate_Acc:0.8438
# Epoch: 10 train_Loss: 0.51465248 train_Accuracy:0.8444
# Epoch: 10 val_Loss:0.53301595,  validate_Acc:0.8103
# Epoch: 11 train_Loss: 0.49016152 train_Accuracy:0.8531
# Epoch: 11 val_Loss:0.50562427,  validate_Acc:0.8571
# Epoch: 12 train_Loss: 0.46669236 train_Accuracy:0.8525
# Epoch: 12 val_Loss:0.48569794,  validate_Acc:0.8371
# Epoch: 13 train_Loss: 0.44223299 train_Accuracy:0.8744
# Epoch: 13 val_Loss:0.45675550,  validate_Acc:0.8013
# Epoch: 14 train_Loss: 0.42642142 train_Accuracy:0.8569
# Epoch: 14 val_Loss:0.43087586,  validate_Acc:0.8929
# Epoch: 15 train_Loss: 0.41447439 train_Accuracy:0.8825
# Epoch: 15 val_Loss:0.41602268,  validate_Acc:0.8951
# Epoch: 16 train_Loss: 0.39426450 train_Accuracy:0.8894
# Epoch: 16 val_Loss:0.39834766,  validate_Acc:0.8482
# Epoch: 17 train_Loss: 0.37720467 train_Accuracy:0.8738
# Epoch: 17 val_Loss:0.43052248,  validate_Acc:0.8482
# Epoch: 18 train_Loss: 0.36201842 train_Accuracy:0.8975
# Epoch: 18 val_Loss:0.37038545,  validate_Acc:0.8817
# Epoch: 19 train_Loss: 0.34779049 train_Accuracy:0.8956
# Epoch: 19 val_Loss:0.36330219,  validate_Acc:0.8862
# Epoch: 20 train_Loss: 0.35648215 train_Accuracy:0.8875
# Epoch: 20 val_Loss:0.37148331,  validate_Acc:0.8839
# Epoch: 21 train_Loss: 0.33765306 train_Accuracy:0.8944
# Epoch: 21 val_Loss:0.34803549,  validate_Acc:0.8772
# Epoch: 22 train_Loss: 0.30758074 train_Accuracy:0.9163
# Epoch: 22 val_Loss:0.31748810,  validate_Acc:0.9040
# Epoch: 23 train_Loss: 0.31157376 train_Accuracy:0.9000
# Epoch: 23 val_Loss:0.32652928,  validate_Acc:0.8772
# Epoch: 24 train_Loss: 0.30355577 train_Accuracy:0.9113
# Epoch: 24 val_Loss:0.30962463,  validate_Acc:0.8906
# Epoch: 25 train_Loss: 0.31101284 train_Accuracy:0.8975
# Epoch: 25 val_Loss:0.31021473,  validate_Acc:0.9018
# Epoch: 26 train_Loss: 0.29000440 train_Accuracy:0.9094
# Epoch: 26 val_Loss:0.29453404,  validate_Acc:0.9129
# Epoch: 27 train_Loss: 0.27102066 train_Accuracy:0.9287
# Epoch: 27 val_Loss:0.24613871,  validate_Acc:0.9375
# Epoch: 28 train_Loss: 0.27562320 train_Accuracy:0.9200
# Epoch: 28 val_Loss:0.29106322,  validate_Acc:0.9062
# Epoch: 29 train_Loss: 0.25634675 train_Accuracy:0.9300
# Epoch: 29 val_Loss:0.25182198,  validate_Acc:0.9286
# Epoch: 30 train_Loss: 0.25568762 train_Accuracy:0.9213
# Epoch: 30 val_Loss:0.31095139,  validate_Acc:0.8549
# Epoch: 31 train_Loss: 0.26294142 train_Accuracy:0.9200
# Epoch: 31 val_Loss:0.25430536,  validate_Acc:0.9263
# Epoch: 32 train_Loss: 0.24260731 train_Accuracy:0.9363
# Epoch: 32 val_Loss:0.24318558,  validate_Acc:0.9219
# Epoch: 33 train_Loss: 0.24108135 train_Accuracy:0.9263
# Epoch: 33 val_Loss:0.23119212,  validate_Acc:0.9308
# Epoch: 34 train_Loss: 0.24263990 train_Accuracy:0.9250
# Epoch: 34 val_Loss:0.24387636,  validate_Acc:0.9241
# Epoch: 35 train_Loss: 0.24946177 train_Accuracy:0.9244
# Epoch: 35 val_Loss:0.26760197,  validate_Acc:0.9040
# Epoch: 36 train_Loss: 0.22954576 train_Accuracy:0.9337
# Epoch: 36 val_Loss:0.20878670,  validate_Acc:0.9308
# Epoch: 37 train_Loss: 0.21968606 train_Accuracy:0.9331
# Epoch: 37 val_Loss:0.21785548,  validate_Acc:0.9375
# Epoch: 38 train_Loss: 0.22217985 train_Accuracy:0.9313
# Epoch: 38 val_Loss:0.19885306,  validate_Acc:0.9330
# Epoch: 39 train_Loss: 0.19573076 train_Accuracy:0.9487
# Epoch: 39 val_Loss:0.19213456,  validate_Acc:0.9464
# Epoch: 40 train_Loss: 0.19197531 train_Accuracy:0.9456
# Epoch: 40 val_Loss:0.20693784,  validate_Acc:0.9554
# Epoch: 41 train_Loss: 0.19815440 train_Accuracy:0.9456
# Epoch: 41 val_Loss:0.20878221,  validate_Acc:0.9509
# Epoch: 42 train_Loss: 0.20319272 train_Accuracy:0.9419
# Epoch: 42 val_Loss:0.21171377,  validate_Acc:0.9442
# Epoch: 43 train_Loss: 0.20394135 train_Accuracy:0.9494
# Epoch: 43 val_Loss:0.22685470,  validate_Acc:0.9219
# Epoch: 44 train_Loss: 0.19122186 train_Accuracy:0.9450
# Epoch: 44 val_Loss:0.19712961,  validate_Acc:0.9353
# Epoch: 45 train_Loss: 0.18692976 train_Accuracy:0.9487
# Epoch: 45 val_Loss:0.21868129,  validate_Acc:0.9129
# Epoch: 46 train_Loss: 0.19995796 train_Accuracy:0.9437
# Epoch: 46 val_Loss:0.17130284,  validate_Acc:0.9554
# Epoch: 47 train_Loss: 0.17919963 train_Accuracy:0.9556
# Epoch: 47 val_Loss:0.20451878,  validate_Acc:0.9263
# Epoch: 48 train_Loss: 0.17372500 train_Accuracy:0.9494
# Epoch: 48 val_Loss:0.21776200,  validate_Acc:0.9263
# Epoch: 49 train_Loss: 0.17962905 train_Accuracy:0.9456
# Epoch: 49 val_Loss:0.15846918,  validate_Acc:0.9554
# Epoch: 50 train_Loss: 0.17088909 train_Accuracy:0.9487
# Epoch: 50 val_Loss:0.18223564,  validate_Acc:0.9442
# Epoch: 51 train_Loss: 0.17391270 train_Accuracy:0.9563
# Epoch: 51 val_Loss:0.18570650,  validate_Acc:0.9375
# Epoch: 52 train_Loss: 0.16638091 train_Accuracy:0.9550
# Epoch: 52 val_Loss:0.17191315,  validate_Acc:0.9375
# Epoch: 53 train_Loss: 0.17805199 train_Accuracy:0.9531
# Epoch: 53 val_Loss:0.14585632,  validate_Acc:0.9487
# Epoch: 54 train_Loss: 0.17148750 train_Accuracy:0.9513
# Epoch: 54 val_Loss:0.18044685,  validate_Acc:0.9509
# Epoch: 55 train_Loss: 0.17033929 train_Accuracy:0.9494
# Epoch: 55 val_Loss:0.15034550,  validate_Acc:0.9732
# Epoch: 56 train_Loss: 0.15668314 train_Accuracy:0.9587
# Epoch: 56 val_Loss:0.15634322,  validate_Acc:0.9621
# Epoch: 57 train_Loss: 0.15448999 train_Accuracy:0.9587
# Epoch: 57 val_Loss:0.16193474,  validate_Acc:0.9397
# Epoch: 58 train_Loss: 0.14652313 train_Accuracy:0.9525
# Epoch: 58 val_Loss:0.14893542,  validate_Acc:0.9688
# Epoch: 59 train_Loss: 0.14206910 train_Accuracy:0.9594
# Epoch: 59 val_Loss:0.14930567,  validate_Acc:0.9621
# Epoch: 60 train_Loss: 0.14732031 train_Accuracy:0.9600
# Epoch: 60 val_Loss:0.15896572,  validate_Acc:0.9509
# Epoch: 61 train_Loss: 0.14833162 train_Accuracy:0.9575
# Epoch: 61 val_Loss:0.12379600,  validate_Acc:0.9554
# Epoch: 62 train_Loss: 0.15312338 train_Accuracy:0.9569
# Epoch: 62 val_Loss:0.16547129,  validate_Acc:0.9353
# Epoch: 63 train_Loss: 0.14805281 train_Accuracy:0.9606
# Epoch: 63 val_Loss:0.15343616,  validate_Acc:0.9531
# Epoch: 64 train_Loss: 0.15027792 train_Accuracy:0.9550
# Epoch: 64 val_Loss:0.14591664,  validate_Acc:0.9598
# Epoch: 65 train_Loss: 0.14744738 train_Accuracy:0.9594
# Epoch: 65 val_Loss:0.15291924,  validate_Acc:0.9554
# Epoch: 66 train_Loss: 0.15268012 train_Accuracy:0.9563
# Epoch: 66 val_Loss:0.21622912,  validate_Acc:0.9241
# Epoch: 67 train_Loss: 0.14765728 train_Accuracy:0.9594
# Epoch: 67 val_Loss:0.16969783,  validate_Acc:0.9308
# Epoch: 68 train_Loss: 0.16444910 train_Accuracy:0.9531
# Epoch: 68 val_Loss:0.14134456,  validate_Acc:0.9598
# Epoch: 69 train_Loss: 0.15131605 train_Accuracy:0.9563
# Epoch: 69 val_Loss:0.14084820,  validate_Acc:0.9665
# Epoch: 70 train_Loss: 0.13819372 train_Accuracy:0.9619
# Epoch: 70 val_Loss:0.14597687,  validate_Acc:0.9710
# Epoch: 71 train_Loss: 0.14309105 train_Accuracy:0.9550
# Epoch: 71 val_Loss:0.12824073,  validate_Acc:0.9732
# Epoch: 72 train_Loss: 0.15176285 train_Accuracy:0.9569
# Epoch: 72 val_Loss:0.15171367,  validate_Acc:0.9531
# Epoch: 73 train_Loss: 0.14332581 train_Accuracy:0.9575
# Epoch: 73 val_Loss:0.14040210,  validate_Acc:0.9621
# Epoch: 74 train_Loss: 0.13780171 train_Accuracy:0.9619
# Epoch: 74 val_Loss:0.11915395,  validate_Acc:0.9754
# Epoch: 75 train_Loss: 0.13395142 train_Accuracy:0.9625
# Epoch: 75 val_Loss:0.12012209,  validate_Acc:0.9754
# Epoch: 76 train_Loss: 0.12205015 train_Accuracy:0.9644
# Epoch: 76 val_Loss:0.13395774,  validate_Acc:0.9487
# Epoch: 77 train_Loss: 0.13512494 train_Accuracy:0.9594
# Epoch: 77 val_Loss:0.11810416,  validate_Acc:0.9732
# Epoch: 78 train_Loss: 0.28016210 train_Accuracy:0.9287
# Epoch: 78 val_Loss:0.14137104,  validate_Acc:0.9643
# Epoch: 79 train_Loss: 0.15886884 train_Accuracy:0.9531
# Epoch: 79 val_Loss:0.14272511,  validate_Acc:0.9576
# Epoch: 80 train_Loss: 0.12277224 train_Accuracy:0.9587
# Epoch: 80 val_Loss:0.12358310,  validate_Acc:0.9688
# Epoch: 81 train_Loss: 0.12109389 train_Accuracy:0.9656
# Epoch: 81 val_Loss:0.11814448,  validate_Acc:0.9665
# Epoch: 82 train_Loss: 0.12321771 train_Accuracy:0.9625
# Epoch: 82 val_Loss:0.12361487,  validate_Acc:0.9643
# Epoch: 83 train_Loss: 0.11939568 train_Accuracy:0.9663
# Epoch: 83 val_Loss:0.12613171,  validate_Acc:0.9688
# Epoch: 84 train_Loss: 0.11789087 train_Accuracy:0.9644
# Epoch: 84 val_Loss:0.10603405,  validate_Acc:0.9576
# Epoch: 85 train_Loss: 0.11840579 train_Accuracy:0.9669
# Epoch: 85 val_Loss:0.11951715,  validate_Acc:0.9621
# Epoch: 86 train_Loss: 0.12908051 train_Accuracy:0.9613
# Epoch: 86 val_Loss:0.11574371,  validate_Acc:0.9799
# Epoch: 87 train_Loss: 0.14179469 train_Accuracy:0.9525
# Epoch: 87 val_Loss:0.12253241,  validate_Acc:0.9688
# Epoch: 88 train_Loss: 0.12352800 train_Accuracy:0.9625
# Epoch: 88 val_Loss:0.12945492,  validate_Acc:0.9576
# Epoch: 89 train_Loss: 0.11611894 train_Accuracy:0.9675
# Epoch: 89 val_Loss:0.12285951,  validate_Acc:0.9688
# Epoch: 90 train_Loss: 0.11993785 train_Accuracy:0.9619
# Epoch: 90 val_Loss:0.12898650,  validate_Acc:0.9732
# Epoch: 91 train_Loss: 0.12142838 train_Accuracy:0.9631
# Epoch: 91 val_Loss:0.13908880,  validate_Acc:0.9531
# Epoch: 92 train_Loss: 0.12615080 train_Accuracy:0.9631
# Epoch: 92 val_Loss:0.10484841,  validate_Acc:0.9799
# Epoch: 93 train_Loss: 0.12187866 train_Accuracy:0.9637
# Epoch: 93 val_Loss:0.10645360,  validate_Acc:0.9799
# Epoch: 94 train_Loss: 0.11551676 train_Accuracy:0.9637
# Epoch: 94 val_Loss:0.10617436,  validate_Acc:0.9754
# Epoch: 95 train_Loss: 0.12113672 train_Accuracy:0.9606
# Epoch: 95 val_Loss:0.17826173,  validate_Acc:0.9330
# Epoch: 96 train_Loss: 0.13656769 train_Accuracy:0.9587
# Epoch: 96 val_Loss:0.18171259,  validate_Acc:0.9464
# Epoch: 97 train_Loss: 0.12969664 train_Accuracy:0.9587
# Epoch: 97 val_Loss:0.15595037,  validate_Acc:0.9487
# Epoch: 98 train_Loss: 0.13075867 train_Accuracy:0.9644
# Epoch: 98 val_Loss:0.11045812,  validate_Acc:0.9799
# Epoch: 99 train_Loss: 0.11549226 train_Accuracy:0.9600
# Epoch: 99 val_Loss:0.13533337,  validate_Acc:0.9487
# Epoch: 100 train_Loss: 0.11657016 train_Accuracy:0.9619
# Epoch: 100 val_Loss:0.12413207,  validate_Acc:0.9688
#
# Duration: 954 seconds
# best_accuracy : 0.9799107142857143

# %%
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix

# 模型 测试集 验证  
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 有GPU先用GPU训练

# 得出每一类的分类准确率
model = torch.load('best_model_cnn1d.pt')
model = model.to(device)

# 使用测试集数据进行推断并计算每一类的分类准确率
class_labels = []  # 存储类别标签
predicted_labels = []  # 存储预测的标签

with torch.no_grad():
    for test_data, test_label in test_loader:
        # 将模型设置为评估模式
        model.eval()
        test_data = test_data.to(device)
        test_output = model(test_data)
        probabilities = F.softmax(test_output, dim=1)
        predicted = torch.argmax(probabilities, dim=1)
        
        class_labels.extend(test_label.tolist())
        predicted_labels.extend(predicted.tolist())

# 混淆矩阵
confusion_mat = confusion_matrix(class_labels, predicted_labels)

from sklearn.metrics import classification_report
# 计算每一类的分类准确率
report = classification_report(class_labels, predicted_labels, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        22
#            1     1.0000    1.0000    1.0000        19
#            2     0.9200    1.0000    0.9583        23
#            3     1.0000    1.0000    1.0000        19
#            4     0.9565    1.0000    0.9778        22
#            5     0.9565    0.7857    0.8627        28
#            6     0.8846    1.0000    0.9388        23
#            7     1.0000    1.0000    1.0000        17
#            8     0.9048    0.8636    0.8837        22
#            9     1.0000    1.0000    1.0000        29
#
#     accuracy                         0.9598       224
#    macro avg     0.9622    0.9649    0.9621       224
# weighted avg     0.9609    0.9598    0.9587       224

# %%
# 绘制混淆矩阵
import matplotlib.pyplot as plt
import seaborn as sns
# 原始标签和自定义标签的映射
label_mapping = {
    0: "C1",1: "C2",2: "C3",3: "C4",4: "C5",
    5: "C6",6: "C7",7: "C8",8: "C9",9: "C10",
}

# 绘制混淆矩阵
plt.figure(figsize=(10, 8), dpi=300)
sns.heatmap(confusion_mat,  xticklabels=label_mapping.values(), yticklabels=label_mapping.values(),annot=True, fmt='d', cmap='summer')
# plt.xlabel('Predicted Labels')
# plt.ylabel('True Labels')
# plt.title('Confusion Matrix')
plt.show()

# %%
# 绘制混淆矩阵
import matplotlib.pyplot as plt
import seaborn as sns
# 原始标签和自定义标签的映射
label_mapping = {
    0: "C1",1: "C2",2: "C3",3: "C4",4: "C5",
    5: "C6",6: "C7",7: "C8",8: "C9",9: "C10",
}

# 绘制混淆矩阵
plt.figure(figsize=(10, 8), dpi=300)
sns.heatmap(confusion_mat,  xticklabels=label_mapping.values(), yticklabels=label_mapping.values(),annot=True, fmt='d', cmap='viridis')
#sns.heatmap(confusion_mat,  xticklabels=label_mapping.values(), yticklabels=label_mapping.values(),annot=True, fmt='d', cmap='summer')
# plt.xlabel('Predicted Labels')
# plt.ylabel('True Labels')
# plt.title('Confusion Matrix')
plt.show()
