# %% [markdown]
# 测试数据和训练数据分组，数据分batch

# %%
import torch
from joblib import dump, load
import torch.utils.data as Data
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
# 参数与配置
torch.manual_seed(100)  # 设置随机种子，以使实验结果具有可重复性
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 有GPU先用GPU训练

# 加载数据集
def dataloader(batch_size, workers=2):
    # 训练集
    train_xdata = load('train_xdata')
    train_ylabel = load('train_ylabel')
    # 验证集
    val_xdata = load('val_xdata')
    val_ylabel = load('val_ylabel')
    # 测试集
    test_xdata = load('test_xdata')
    test_ylabel = load('test_ylabel')

    # 加载数据
    train_loader = Data.DataLoader(dataset=Data.TensorDataset(train_xdata, train_ylabel),
                                   batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    val_loader = Data.DataLoader(dataset=Data.TensorDataset(val_xdata, val_ylabel),
                                 batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    test_loader = Data.DataLoader(dataset=Data.TensorDataset(test_xdata, test_ylabel),
                                  batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    return train_loader, val_loader, test_loader

batch_size = 64
# 加载数据
train_loader, val_loader, test_loader = dataloader(batch_size)

print(len(train_loader))
print(len(val_loader))
print(len(test_loader))
# Out:
# 111
# 31
# 15

# %%
import torch
from joblib import dump, load
import torch.utils.data as Data
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# 定义CNN-1D模型
class CNN1DModel(nn.Module):
    def __init__(self, conv_archs, num_classes, input_channels=1):
        super().__init__()
         # CNN参数
        self.conv_arch = conv_archs # 网络结构
        self.input_channels = input_channels # 输入通道数
        self.features = self.make_layers()
        # 平均池化
        self.avgpool = nn.AdaptiveAvgPool1d(1)
        # 线性层
        self.classifier = nn.Linear(conv_archs[-1][-1], num_classes)
        
    # CNN卷积池化结构
    def make_layers(self):
        layers = []
        for (num_convs, out_channels) in self.conv_arch:
            for _ in range(num_convs):
                layers.append(nn.Conv1d(self.input_channels, out_channels, kernel_size=3, padding=1))
                layers.append(nn.ReLU(inplace=True))
                self.input_channels = out_channels
            layers.append(nn.MaxPool1d(kernel_size=2, stride=2)) # 这里会使宽高减半
        return nn.Sequential(*layers)
    

    def forward(self,input_seq):  # torch.Size([64, 1024])
        batch_size = input_seq.size(0)
        seq_length = input_seq.size(1)

        #改变输入形状，适应网络输入[batch, dim, seq_length]
        input_seq = input_seq.view(batch_size , -1, seq_length)   # torch.Size([64, 1, 1024])
        features = self.features(input_seq)  # [64, 128, 128]
        # print(features.size())  # torch.Size([64, 128, 128])
        x = self.avgpool(features)          # ttorch.Size([64, 128, 1])
        # print(x.size())  # torch.Size([64, 128, 1])
        flat_tensor = x.view(batch_size, -1) # torch.Size([64, 128])
        output = self.classifier(flat_tensor)    # torch.Size([64, 5])
        return output

# %% [markdown]
# 输入数据的形状是
#  1. print(seq.size(), labels.size())
#  2. torch.Size([64, 1024])   torch.Size([64])

# %%
# 定义模型参数
# VGG11，VGG13，VGG16，VGG19 可自行更换。
#conv_arch = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))  # vgg11
#conv_arch = ((2, 64), (2, 128), (2 , 256), (2, 512), (2, 512))  # vgg13
#conv_arch = ((2, 64), (2, 128), (3, 256), (3, 512), (3, 512))  # vgg16
#conv_arch = ((2, 64), (2, 128), (4, 256), (4, 512), (4, 512))  # vgg19
# 先用浅层试一试
conv_arch = ((2, 32), (1, 64), (1, 128))  
input_channels = 1
num_classes = 5

model = CNN1DModel(conv_arch, num_classes, input_channels)  
# 定义损失函数和优化函数 
loss_function = nn.CrossEntropyLoss(reduction='sum')  # loss
loss_function = loss_function.to(device)
learn_rate = 0.0003
optimizer = torch.optim.Adam(model.parameters(), learn_rate)  # 优化器

# 看下这个网络结构总共有多少个参数
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')

count_parameters(model)
# Out:
#     96
#     32
#   3072
#     32
#   6144
#     64
#  24576
#    128
#    640
#      5
# ______
#  34789

# %%
print(model)
# Out:
# CNN1DModel(
#   (features): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (3): ReLU(inplace=True)
#     (4): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (6): ReLU(inplace=True)
#     (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU(inplace=True)
#     (10): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool1d(output_size=1)
#   (classifier): Linear(in_features=128, out_features=5, bias=True)
# )

# %% [markdown]
# 注意调整参数，
# 1. 可以适当增加 cnn层数 和每层神经元个数，微调学习率；
# 2. 增加更多的 epochs,  （注意防止过拟合）

# %%
# 训练模型
import time
import torch.nn.functional as F
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc("font", family='Microsoft YaHei')

def model_train(batch_size, epochs, train_loader, val_loader, model, optimizer, loss_function):
    model = model.to(device)
    # 样本长度
    train_size = len(train_loader) * batch_size
    val_size = len(val_loader) * batch_size

    # 最高准确率  最佳模型
    best_accuracy = 0.0
    best_model = model

    train_loss = []     # 记录在训练集上每个epoch的loss的变化情况
    train_acc = []    # 记录在训练集上每个epoch的准确率的变化情况
    validate_acc = []
    validate_loss = []

    # 计算模型运行时间
    start_time = time.time()
    for epoch in range(epochs):
        # 训练
        model.train()

        loss_epoch = 0.    #保存当前epoch的loss和
        correct_epoch = 0  #保存当前epoch的正确个数和
        for seq, labels in train_loader: 
            seq, labels = seq.to(device), labels.to(device)
            # print(seq.size(), labels.size()) torch.Size([32, 7, 1024]) torch.Size([32])
            # 每次更新参数前都梯度归零和初始化
            optimizer.zero_grad()
            # 前向传播
            y_pred = model(seq)  #   torch.Size([16, 10])
            # 对模型输出进行softmax操作，得到概率分布
            probabilities = F.softmax(y_pred, dim=1)
            # 得到预测的类别
            predicted_labels = torch.argmax(probabilities, dim=1)
            # 与真实标签进行比较，计算预测正确的样本数量  # 计算当前batch预测正确个数
            correct_epoch += (predicted_labels == labels).sum().item()
            # 损失计算
            loss = loss_function(y_pred, labels)
            loss_epoch += loss.item()
            # 反向传播和参数更新
            loss.backward()
            optimizer.step()
        #     break
        # break
        # 计算准确率
        train_Accuracy  = correct_epoch/train_size 
        train_loss.append(loss_epoch/train_size)
        train_acc.append(train_Accuracy)
        print(f'Epoch: {epoch+1:2} train_Loss: {loss_epoch/train_size:10.8f} train_Accuracy:{train_Accuracy:4.4f}')
        # 每一个epoch结束后，在验证集上验证实验结果。
        with torch.no_grad():
            loss_validate = 0.
            correct_validate = 0
            # 将模型设置为评估模式
            model.eval()
            for data, label in val_loader:
                data, label = data.to(device), label.to(device)
                pre = model(data)
                # 对模型输出进行softmax操作，得到概率分布
                probabilities = F.softmax(pre, dim=1)
                # 得到预测的类别
                predicted_labels = torch.argmax(probabilities, dim=1)
                # 与真实标签进行比较，计算预测正确的样本数量  # 计算当前batch预测正确个数
                correct_validate += (predicted_labels == label).sum().item()
                loss = loss_function(pre, label)
                loss_validate += loss.item()
            # print(f'validate_sum:{loss_validate},  validate_Acc:{correct_validate}')
            val_accuracy = correct_validate/val_size 
            print(f'Epoch: {epoch+1:2} val_Loss:{loss_validate/val_size:10.8f},  validate_Acc:{val_accuracy:4.4f}')
            validate_loss.append(loss_validate/val_size)
            validate_acc.append(val_accuracy)
            # 如果当前模型的准确率优于之前的最佳准确率，则更新最佳模型
            #保存当前最优模型参数
            if val_accuracy > best_accuracy:
                best_accuracy = val_accuracy
                best_model = model# 更新最佳模型的参数

    
    # 保存最后的参数
    # torch.save(model, 'final_model_cnn1d.pt')
    # 保存最好的参数
    torch.save(best_model, 'best_model_cnn1d.pt')
   
    print(f'\nDuration: {time.time() - start_time:.0f} seconds')
    plt.plot(range(epochs), train_loss, color = 'b',label = 'train_loss')
    plt.plot(range(epochs), train_acc, color = 'g',label = 'train_acc')
    plt.plot(range(epochs), validate_loss, color = 'y',label = 'validate_loss')
    plt.plot(range(epochs), validate_acc, color = 'r',label = 'validate_acc')
    plt.legend()
    plt.show()   #显示 lable 
    print("best_accuracy :", best_accuracy)



batch_size = 64
epochs = 100
# 模型训练
model_train(batch_size, epochs, train_loader, val_loader, model, optimizer, loss_function)
# Out:
# Epoch:  1 train_Loss: 1.61020568 train_Accuracy:0.1990
# Epoch:  1 val_Loss:1.61007810,  validate_Acc:0.2006
# Epoch:  2 train_Loss: 1.60996074 train_Accuracy:0.1990
# Epoch:  2 val_Loss:1.60983387,  validate_Acc:0.1935
# Epoch:  3 train_Loss: 1.60978959 train_Accuracy:0.1966
# Epoch:  3 val_Loss:1.60948066,  validate_Acc:0.1925
# Epoch:  4 train_Loss: 1.60961739 train_Accuracy:0.1969
# Epoch:  4 val_Loss:1.61000551,  validate_Acc:0.2021
# Epoch:  5 train_Loss: 1.60934660 train_Accuracy:0.2043
# Epoch:  5 val_Loss:1.60940745,  validate_Acc:0.1925
# Epoch:  6 train_Loss: 1.60922386 train_Accuracy:0.1983
# Epoch:  6 val_Loss:1.60928900,  validate_Acc:0.1890
# Epoch:  7 train_Loss: 1.60833238 train_Accuracy:0.2043
# Epoch:  7 val_Loss:1.60790323,  validate_Acc:0.2016
# Epoch:  8 train_Loss: 1.60771149 train_Accuracy:0.2010
# Epoch:  8 val_Loss:1.60723822,  validate_Acc:0.1830
# Epoch:  9 train_Loss: 1.60690418 train_Accuracy:0.2054
# Epoch:  9 val_Loss:1.60709503,  validate_Acc:0.2026
# Epoch: 10 train_Loss: 1.60755651 train_Accuracy:0.2083
# Epoch: 10 val_Loss:1.60797829,  validate_Acc:0.2021
# Epoch: 11 train_Loss: 1.60757477 train_Accuracy:0.2027
# Epoch: 11 val_Loss:1.60716601,  validate_Acc:0.2056
# Epoch: 12 train_Loss: 1.60724719 train_Accuracy:0.2188
# Epoch: 12 val_Loss:1.60631213,  validate_Acc:0.3891
# Epoch: 13 train_Loss: 1.60650265 train_Accuracy:0.2176
# Epoch: 13 val_Loss:1.60439339,  validate_Acc:0.1935
# Epoch: 14 train_Loss: 1.60457547 train_Accuracy:0.2438
# Epoch: 14 val_Loss:1.60285981,  validate_Acc:0.3942
# Epoch: 15 train_Loss: 1.59442423 train_Accuracy:0.2987
# Epoch: 15 val_Loss:1.58040028,  validate_Acc:0.2233
# Epoch: 16 train_Loss: 1.52570141 train_Accuracy:0.3111
# Epoch: 16 val_Loss:1.40811552,  validate_Acc:0.3584
# Epoch: 17 train_Loss: 1.25346886 train_Accuracy:0.4324
# Epoch: 17 val_Loss:1.08961807,  validate_Acc:0.5408
# Epoch: 18 train_Loss: 0.96889608 train_Accuracy:0.5539
# Epoch: 18 val_Loss:0.85994326,  validate_Acc:0.6532
# Epoch: 19 train_Loss: 0.80807297 train_Accuracy:0.5983
# Epoch: 19 val_Loss:0.77325490,  validate_Acc:0.5741
# Epoch: 20 train_Loss: 0.72357361 train_Accuracy:0.6402
# Epoch: 20 val_Loss:0.70651533,  validate_Acc:0.6633
# Epoch: 21 train_Loss: 0.67648690 train_Accuracy:0.6665
# Epoch: 21 val_Loss:0.70596422,  validate_Acc:0.6295
# Epoch: 22 train_Loss: 0.64396285 train_Accuracy:0.6881
# Epoch: 22 val_Loss:0.64672911,  validate_Acc:0.6678
# Epoch: 23 train_Loss: 0.61903400 train_Accuracy:0.7079
# Epoch: 23 val_Loss:0.61282687,  validate_Acc:0.7374
# Epoch: 24 train_Loss: 0.61302389 train_Accuracy:0.7072
# Epoch: 24 val_Loss:0.63701495,  validate_Acc:0.6734
# Epoch: 25 train_Loss: 0.59436098 train_Accuracy:0.7299
# Epoch: 25 val_Loss:0.58464953,  validate_Acc:0.7747
# Epoch: 26 train_Loss: 0.57659307 train_Accuracy:0.7475
# Epoch: 26 val_Loss:0.57052521,  validate_Acc:0.7732
# Epoch: 27 train_Loss: 0.55763998 train_Accuracy:0.7630
# Epoch: 27 val_Loss:0.54816528,  validate_Acc:0.7994
# Epoch: 28 train_Loss: 0.54021216 train_Accuracy:0.7774
# Epoch: 28 val_Loss:0.54657810,  validate_Acc:0.7908
# Epoch: 29 train_Loss: 0.52401428 train_Accuracy:0.7914
# Epoch: 29 val_Loss:0.52205934,  validate_Acc:0.8105
# Epoch: 30 train_Loss: 0.50608300 train_Accuracy:0.8083
# Epoch: 30 val_Loss:0.49376079,  validate_Acc:0.8342
# Epoch: 31 train_Loss: 0.49053644 train_Accuracy:0.8160
# Epoch: 31 val_Loss:0.50814510,  validate_Acc:0.8115
# Epoch: 32 train_Loss: 0.47091523 train_Accuracy:0.8287
# Epoch: 32 val_Loss:0.46461244,  validate_Acc:0.8574
# Epoch: 33 train_Loss: 0.45754073 train_Accuracy:0.8377
# Epoch: 33 val_Loss:0.45545031,  validate_Acc:0.8453
# Epoch: 34 train_Loss: 0.43667482 train_Accuracy:0.8529
# Epoch: 34 val_Loss:0.42776284,  validate_Acc:0.8609
# Epoch: 35 train_Loss: 0.43303850 train_Accuracy:0.8439
# Epoch: 35 val_Loss:0.41756783,  validate_Acc:0.8735
# Epoch: 36 train_Loss: 0.42783857 train_Accuracy:0.8476
# Epoch: 36 val_Loss:0.44381412,  validate_Acc:0.8584
# Epoch: 37 train_Loss: 0.40317115 train_Accuracy:0.8591
# Epoch: 37 val_Loss:0.40192926,  validate_Acc:0.8785
# Epoch: 38 train_Loss: 0.38658357 train_Accuracy:0.8630
# Epoch: 38 val_Loss:0.38837821,  validate_Acc:0.8740
# Epoch: 39 train_Loss: 0.38099023 train_Accuracy:0.8694
# Epoch: 39 val_Loss:0.37425263,  validate_Acc:0.8725
# Epoch: 40 train_Loss: 0.36778633 train_Accuracy:0.8706
# Epoch: 40 val_Loss:0.36013870,  validate_Acc:0.8795
# Epoch: 41 train_Loss: 0.34985717 train_Accuracy:0.8777
# Epoch: 41 val_Loss:0.35204592,  validate_Acc:0.8901
# Epoch: 42 train_Loss: 0.34749248 train_Accuracy:0.8765
# Epoch: 42 val_Loss:0.34091832,  validate_Acc:0.8896
# Epoch: 43 train_Loss: 0.33951864 train_Accuracy:0.8808
# Epoch: 43 val_Loss:0.34814322,  validate_Acc:0.8831
# Epoch: 44 train_Loss: 0.33177598 train_Accuracy:0.8798
# Epoch: 44 val_Loss:0.32320877,  validate_Acc:0.8936
# Epoch: 45 train_Loss: 0.32752346 train_Accuracy:0.8780
# Epoch: 45 val_Loss:0.32110679,  validate_Acc:0.8851
# Epoch: 46 train_Loss: 0.32593352 train_Accuracy:0.8806
# Epoch: 46 val_Loss:0.31563741,  validate_Acc:0.8906
# Epoch: 47 train_Loss: 0.32019641 train_Accuracy:0.8785
# Epoch: 47 val_Loss:0.32177960,  validate_Acc:0.8826
# Epoch: 48 train_Loss: 0.31042806 train_Accuracy:0.8830
# Epoch: 48 val_Loss:0.33010151,  validate_Acc:0.8805
# Epoch: 49 train_Loss: 0.31314283 train_Accuracy:0.8816
# Epoch: 49 val_Loss:0.29966508,  validate_Acc:0.8962
# Epoch: 50 train_Loss: 0.29937534 train_Accuracy:0.8854
# Epoch: 50 val_Loss:0.30392307,  validate_Acc:0.8911
# Epoch: 51 train_Loss: 0.31794452 train_Accuracy:0.8799
# Epoch: 51 val_Loss:0.32130065,  validate_Acc:0.8750
# Epoch: 52 train_Loss: 0.29492843 train_Accuracy:0.8860
# Epoch: 52 val_Loss:0.35198068,  validate_Acc:0.8629
# Epoch: 53 train_Loss: 0.28790321 train_Accuracy:0.8915
# Epoch: 53 val_Loss:0.29560586,  validate_Acc:0.8896
# Epoch: 54 train_Loss: 0.28579270 train_Accuracy:0.8895
# Epoch: 54 val_Loss:0.27413727,  validate_Acc:0.8992
# Epoch: 55 train_Loss: 0.28760284 train_Accuracy:0.8926
# Epoch: 55 val_Loss:0.28597546,  validate_Acc:0.8997
# Epoch: 56 train_Loss: 0.30194861 train_Accuracy:0.8795
# Epoch: 56 val_Loss:0.27840669,  validate_Acc:0.8947
# Epoch: 57 train_Loss: 0.28311217 train_Accuracy:0.8891
# Epoch: 57 val_Loss:0.27614283,  validate_Acc:0.8931
# Epoch: 58 train_Loss: 0.27281429 train_Accuracy:0.8932
# Epoch: 58 val_Loss:0.27356687,  validate_Acc:0.8957
# Epoch: 59 train_Loss: 0.28553270 train_Accuracy:0.8880
# Epoch: 59 val_Loss:0.30064867,  validate_Acc:0.8856
# Epoch: 60 train_Loss: 0.27231111 train_Accuracy:0.8923
# Epoch: 60 val_Loss:0.27681515,  validate_Acc:0.8967
# Epoch: 61 train_Loss: 0.27004453 train_Accuracy:0.8964
# Epoch: 61 val_Loss:0.26185292,  validate_Acc:0.9002
# Epoch: 62 train_Loss: 0.27624725 train_Accuracy:0.8902
# Epoch: 62 val_Loss:0.29352583,  validate_Acc:0.8816
# Epoch: 63 train_Loss: 0.26672312 train_Accuracy:0.8954
# Epoch: 63 val_Loss:0.29511005,  validate_Acc:0.8896
# Epoch: 64 train_Loss: 0.27469788 train_Accuracy:0.8889
# Epoch: 64 val_Loss:0.30346693,  validate_Acc:0.8846
# Epoch: 65 train_Loss: 0.27142060 train_Accuracy:0.8908
# Epoch: 65 val_Loss:0.28202705,  validate_Acc:0.8926
# Epoch: 66 train_Loss: 0.26893809 train_Accuracy:0.8939
# Epoch: 66 val_Loss:0.29146875,  validate_Acc:0.8891
# Epoch: 67 train_Loss: 0.26797708 train_Accuracy:0.8913
# Epoch: 67 val_Loss:0.27548592,  validate_Acc:0.8911
# Epoch: 68 train_Loss: 0.26321811 train_Accuracy:0.8968
# Epoch: 68 val_Loss:0.26899866,  validate_Acc:0.8947
# Epoch: 69 train_Loss: 0.26477322 train_Accuracy:0.8967
# Epoch: 69 val_Loss:0.26722378,  validate_Acc:0.8931
# Epoch: 70 train_Loss: 0.26632027 train_Accuracy:0.8950
# Epoch: 70 val_Loss:0.28262487,  validate_Acc:0.8876
# Epoch: 71 train_Loss: 0.26238425 train_Accuracy:0.8965
# Epoch: 71 val_Loss:0.26644950,  validate_Acc:0.8947
# Epoch: 72 train_Loss: 0.26664340 train_Accuracy:0.8950
# Epoch: 72 val_Loss:0.36151197,  validate_Acc:0.8483
# Epoch: 73 train_Loss: 0.26486737 train_Accuracy:0.8937
# Epoch: 73 val_Loss:0.27993656,  validate_Acc:0.8931
# Epoch: 74 train_Loss: 0.25992846 train_Accuracy:0.8933
# Epoch: 74 val_Loss:0.24974655,  validate_Acc:0.9017
# Epoch: 75 train_Loss: 0.25994434 train_Accuracy:0.8984
# Epoch: 75 val_Loss:0.25834271,  validate_Acc:0.9002
# Epoch: 76 train_Loss: 0.26252079 train_Accuracy:0.8967
# Epoch: 76 val_Loss:0.24981744,  validate_Acc:0.9032
# Epoch: 77 train_Loss: 0.24962992 train_Accuracy:0.9005
# Epoch: 77 val_Loss:0.29346078,  validate_Acc:0.8836
# Epoch: 78 train_Loss: 0.25868211 train_Accuracy:0.8947
# Epoch: 78 val_Loss:0.26496304,  validate_Acc:0.8916
# Epoch: 79 train_Loss: 0.26659357 train_Accuracy:0.8920
# Epoch: 79 val_Loss:0.25083198,  validate_Acc:0.9002
# Epoch: 80 train_Loss: 0.25184057 train_Accuracy:0.8999
# Epoch: 80 val_Loss:0.25149351,  validate_Acc:0.9042
# Epoch: 81 train_Loss: 0.26255043 train_Accuracy:0.8956
# Epoch: 81 val_Loss:0.27054772,  validate_Acc:0.8952
# Epoch: 82 train_Loss: 0.25532236 train_Accuracy:0.8954
# Epoch: 82 val_Loss:0.24875308,  validate_Acc:0.9037
# Epoch: 83 train_Loss: 0.25298667 train_Accuracy:0.8975
# Epoch: 83 val_Loss:0.24813232,  validate_Acc:0.9042
# Epoch: 84 train_Loss: 0.25176394 train_Accuracy:0.8979
# Epoch: 84 val_Loss:0.24136778,  validate_Acc:0.9078
# Epoch: 85 train_Loss: 0.24551440 train_Accuracy:0.9053
# Epoch: 85 val_Loss:0.25224056,  validate_Acc:0.8977
# Epoch: 86 train_Loss: 0.25863820 train_Accuracy:0.8972
# Epoch: 86 val_Loss:0.23952923,  validate_Acc:0.9042
# Epoch: 87 train_Loss: 0.25161583 train_Accuracy:0.9008
# Epoch: 87 val_Loss:0.24090119,  validate_Acc:0.9078
# Epoch: 88 train_Loss: 0.25549881 train_Accuracy:0.8960
# Epoch: 88 val_Loss:0.24369165,  validate_Acc:0.9068
# Epoch: 89 train_Loss: 0.25014748 train_Accuracy:0.9019
# Epoch: 89 val_Loss:0.25194038,  validate_Acc:0.9083
# Epoch: 90 train_Loss: 0.24135401 train_Accuracy:0.9047
# Epoch: 90 val_Loss:0.23675269,  validate_Acc:0.9083
# Epoch: 91 train_Loss: 0.23965172 train_Accuracy:0.9032
# Epoch: 91 val_Loss:0.24454011,  validate_Acc:0.9062
# Epoch: 92 train_Loss: 0.24887580 train_Accuracy:0.8970
# Epoch: 92 val_Loss:0.24101560,  validate_Acc:0.9042
# Epoch: 93 train_Loss: 0.25292103 train_Accuracy:0.8964
# Epoch: 93 val_Loss:0.24173929,  validate_Acc:0.9057
# Epoch: 94 train_Loss: 0.24279145 train_Accuracy:0.9016
# Epoch: 94 val_Loss:0.23997524,  validate_Acc:0.9022
# Epoch: 95 train_Loss: 0.24903076 train_Accuracy:0.8989
# Epoch: 95 val_Loss:0.25704161,  validate_Acc:0.8957
# Epoch: 96 train_Loss: 0.23839050 train_Accuracy:0.9027
# Epoch: 96 val_Loss:0.24777081,  validate_Acc:0.9002
# Epoch: 97 train_Loss: 0.23551315 train_Accuracy:0.9067
# Epoch: 97 val_Loss:0.23829202,  validate_Acc:0.9098
# Epoch: 98 train_Loss: 0.23887697 train_Accuracy:0.9041
# Epoch: 98 val_Loss:0.23606077,  validate_Acc:0.9068
# Epoch: 99 train_Loss: 0.24964079 train_Accuracy:0.8995
# Epoch: 99 val_Loss:0.24214394,  validate_Acc:0.9052
# Epoch: 100 train_Loss: 0.24099391 train_Accuracy:0.9057
# Epoch: 100 val_Loss:0.23615296,  validate_Acc:0.9052
#
# Duration: 585 seconds
# best_accuracy : 0.9097782258064516

# %%
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix

# 模型 测试集 验证  
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 有GPU先用GPU训练

# 得出每一类的分类准确率
model = torch.load('best_model_cnn1d.pt')
model = model.to(device)

# 使用测试集数据进行推断并计算每一类的分类准确率
class_labels = []  # 存储类别标签
predicted_labels = []  # 存储预测的标签

with torch.no_grad():
    for test_data, test_label in test_loader:
        # 将模型设置为评估模式
        model.eval()
        test_data = test_data.to(device)
        test_output = model(test_data)
        probabilities = F.softmax(test_output, dim=1)
        predicted = torch.argmax(probabilities, dim=1)
        
        class_labels.extend(test_label.tolist())
        predicted_labels.extend(predicted.tolist())

# 混淆矩阵
confusion_mat = confusion_matrix(class_labels, predicted_labels)

from sklearn.metrics import classification_report
# 计算每一类的分类准确率
report = classification_report(class_labels, predicted_labels, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       202
#            1     0.8564    0.9153    0.8849       189
#            2     0.8280    0.8021    0.8148       192
#            3     0.8511    0.8377    0.8443       191
#            4     0.9505    0.9301    0.9402       186
#
#     accuracy                         0.8979       960
#    macro avg     0.8972    0.8970    0.8969       960
# weighted avg     0.8981    0.8979    0.8977       960

# %%
# 绘制混淆矩阵
import matplotlib.pyplot as plt
import seaborn as sns
# 原始标签和自定义标签的映射
label_mapping = {
    0: "C1",1: "C2",2: "C3",3: "C4",4: "C5",
}

# 绘制混淆矩阵
plt.figure(figsize=(5, 4), dpi=300)
sns.heatmap(confusion_mat,  xticklabels=label_mapping.values(), yticklabels=label_mapping.values(),annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix of 1DCNN-load')
plt.savefig("cnn1d_confusion.png")
plt.show()

# %%
# 绘制混淆矩阵
import matplotlib.pyplot as plt
import seaborn as sns
# 原始标签和自定义标签的映射
label_mapping = {
    0: "C1",1: "C2",2: "C3",3: "C4",4: "C5",
}

# 绘制混淆矩阵
plt.figure(figsize=(10, 8), dpi=300)
sns.heatmap(confusion_mat,  xticklabels=label_mapping.values(), yticklabels=label_mapping.values(),annot=True, fmt='d', cmap='viridis')
# plt.xlabel('Predicted Labels')
# plt.ylabel('True Labels')
# plt.title('Confusion Matrix')
plt.show()
