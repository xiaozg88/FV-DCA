# %% [markdown]
# 测试数据和训练数据分组，数据分batch

# %%
import torch
from joblib import dump, load
import torch.utils.data as Data
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
# 参数与配置
torch.manual_seed(100)  # 设置随机种子，以使实验结果具有可重复性
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 有GPU先用GPU训练

# 加载数据集
def dataloader(batch_size, workers=2):
    # 训练集
    train_xdata = load('train_xdata')
    train_ylabel = load('train_ylabel')
    # 验证集
    val_xdata = load('val_xdata')
    val_ylabel = load('val_ylabel')
    # 测试集
    test_xdata = load('test_xdata')
    test_ylabel = load('test_ylabel')

    # 加载数据
    train_loader = Data.DataLoader(dataset=Data.TensorDataset(train_xdata, train_ylabel),
                                   batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    val_loader = Data.DataLoader(dataset=Data.TensorDataset(val_xdata, val_ylabel),
                                 batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    test_loader = Data.DataLoader(dataset=Data.TensorDataset(test_xdata, test_ylabel),
                                  batch_size=batch_size, shuffle=True, num_workers=workers, drop_last=True)
    return train_loader, val_loader, test_loader

batch_size = 64
# 加载数据
train_loader, val_loader, test_loader = dataloader(batch_size)

print(len(train_loader))
print(len(val_loader))
print(len(test_loader))
# Out:
# 111
# 31
# 15

# %% [markdown]
# 定义CNN-2D 分类网络架构

# %%
# 定义CNN-2D模型
class CNN2DModel(nn.Module):
    def __init__(self, conv_archs, num_classes, input_channels=1):
        super(CNN2DModel, self).__init__()
        self.conv_arch = conv_archs # 网络结构
        self.input_channels = input_channels # 输入通道数
        self.features = self.make_layers()

        # 平均池化
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # 线性层
        self.classifier = nn.Linear(conv_archs[-1][-1], num_classes)

    def make_layers(self):
        layers = []
        for (num_convs, out_channels) in self.conv_arch:
            for _ in range(num_convs):
                layers.append(nn.Conv2d(self.input_channels, out_channels, kernel_size=3, padding=1))
                layers.append(nn.ReLU(inplace=True))
                self.input_channels = out_channels
            layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
        return nn.Sequential(*layers)

    def forward(self,input_seq):
        batch_size = input_seq.size(0)
        #改变输入形状，适应网络输入[batch, channels, seq_length, H_in]
        # 注意：这里是 把数据进行了堆叠 把一个1*1024 的序列 进行 划分堆叠成形状为 32 * 32， 就使输入序列的长度降下来了 ; 1代表通道数
        input_seq = input_seq.view(batch_size, 1, 32, 32)
        input_seq = torch.transpose(input_seq, 2, 3)  # 反转维度 和序列长度 ，适应网络输入形状
        
        features = self.features(input_seq) # torch.Size([64, 128, 4, 4])
        x = self.avgpool(features)          # torch.Size([64, 128, 1, 1])
        flat_tensor = x.view(batch_size, -1) # torch.Size([64, 128])
        output = self.classifier(flat_tensor)    # torch.Size([64, 5])
        return output

# %% [markdown]
# 输入数据的形状是
#  1. print(seq.size(), labels.size())
#  2. torch.Size([32, 1, 1024])    torch.Size([32])

# %%
# 定义模型参数
input_dim = 32   # 输入维度为一维信号序列堆叠为 32 * 32
# VGG11，VGG13，VGG16，VGG19 可自行更换。
#conv_archs = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))  # vgg11
#conv_archs = ((2, 64), (2, 128), (2 , 256), (2, 512), (2, 512))  # vgg13
#conv_archs = ((2, 64), (2, 128), (3, 256), (3, 512), (3, 512))  # vgg16
#conv_archs = ((2, 64), (2, 128), (4, 256), (4, 512), (4, 512))  # vgg19
# 先用浅层试一试
conv_archs = ((2, 32), (1, 64), (1, 128))  
input_channels = 1
num_classes = 5

model = CNN2DModel(conv_archs, num_classes, input_channels)  
# 定义损失函数和优化函数 
loss_function = nn.CrossEntropyLoss(reduction='sum')  # loss
learn_rate = 0.0003
optimizer = torch.optim.Adam(model.parameters(), learn_rate)  # 优化器

# 看下这个网络结构总共有多少个参数
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')

count_parameters(model)
# Out:
#    288
#     32
#   9216
#     32
#  18432
#     64
#  73728
#    128
#    640
#      5
# ______
# 102565

# %%
print(model)
# Out:
# CNN2DModel(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Linear(in_features=128, out_features=5, bias=True)
# )

# %% [markdown]
# 注意调整参数，
# 1. 可以适当增加 CNN层数 和每层神经元个数，微调学习率；
# 2. 增加更多的 epochs,  （注意防止过拟合）

# %%
# 训练模型
import time
import torch.nn.functional as F
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc("font", family='Microsoft YaHei')

def model_train(batch_size, epochs, train_loader, val_loader, model, optimizer, loss_function):
    model = model.to(device)
    # 样本长度
    train_size = len(train_loader) * batch_size
    val_size = len(val_loader) * batch_size

    # 最高准确率  最佳模型
    best_accuracy = 0.0
    best_model = model

    train_loss = []     # 记录在训练集上每个epoch的loss的变化情况
    train_acc = []    # 记录在训练集上每个epoch的准确率的变化情况
    validate_acc = []
    validate_loss = []

    # 计算模型运行时间
    start_time = time.time()
    for epoch in range(epochs):
        # 训练
        model.train()

        loss_epoch = 0.    #保存当前epoch的loss和
        correct_epoch = 0  #保存当前epoch的正确个数和
        for seq, labels in train_loader: 
            seq, labels = seq.to(device), labels.to(device)
            # print(seq.size(), labels.size()) torch.Size([32, 7, 1024]) torch.Size([32])
            # 每次更新参数前都梯度归零和初始化
            optimizer.zero_grad()
            # 前向传播
            y_pred = model(seq)  #   torch.Size([16, 10])
            # 对模型输出进行softmax操作，得到概率分布
            probabilities = F.softmax(y_pred, dim=1)
            # 得到预测的类别
            predicted_labels = torch.argmax(probabilities, dim=1)
            # 与真实标签进行比较，计算预测正确的样本数量  # 计算当前batch预测正确个数
            correct_epoch += (predicted_labels == labels).sum().item()
            # 损失计算
            loss = loss_function(y_pred, labels)
            loss_epoch += loss.item()
            # 反向传播和参数更新
            loss.backward()
            optimizer.step()
        #     break
        # break
        # 计算准确率
        train_Accuracy  = correct_epoch/train_size 
        train_loss.append(loss_epoch/train_size)
        train_acc.append(train_Accuracy)
        print(f'Epoch: {epoch+1:2} train_Loss: {loss_epoch/train_size:10.8f} train_Accuracy:{train_Accuracy:4.4f}')
        # 每一个epoch结束后，在验证集上验证实验结果。
        with torch.no_grad():
            loss_validate = 0.
            correct_validate = 0
            # 将模型设置为评估模式
            model.eval()
            for data, label in val_loader:
                data, label = data.to(device), label.to(device)
                pre = model(data)
                # 对模型输出进行softmax操作，得到概率分布
                probabilities = F.softmax(pre, dim=1)
                # 得到预测的类别
                predicted_labels = torch.argmax(probabilities, dim=1)
                # 与真实标签进行比较，计算预测正确的样本数量  # 计算当前batch预测正确个数
                correct_validate += (predicted_labels == label).sum().item()
                loss = loss_function(pre, label)
                loss_validate += loss.item()
            # print(f'validate_sum:{loss_validate},  validate_Acc:{correct_validate}')
            val_accuracy = correct_validate/val_size 
            print(f'Epoch: {epoch+1:2} val_Loss:{loss_validate/val_size:10.8f},  validate_Acc:{val_accuracy:4.4f}')
            validate_loss.append(loss_validate/val_size)
            validate_acc.append(val_accuracy)
            # 如果当前模型的准确率优于之前的最佳准确率，则更新最佳模型
            #保存当前最优模型参数
            if val_accuracy > best_accuracy:
                best_accuracy = val_accuracy
                best_model = model# 更新最佳模型的参数

    
    # 保存最后的参数
    # torch.save(model, 'final_model_cnn2d.pt')
    # 保存最好的参数
    torch.save(best_model, 'best_model_cnn2d.pt')
   
    print(f'\nDuration: {time.time() - start_time:.0f} seconds')
    plt.plot(range(epochs), train_loss, color = 'b',label = 'train_loss')
    plt.plot(range(epochs), train_acc, color = 'g',label = 'train_acc')
    plt.plot(range(epochs), validate_loss, color = 'y',label = 'validate_loss')
    plt.plot(range(epochs), validate_acc, color = 'r',label = 'validate_acc')
    plt.legend()
    plt.show()   #显示 lable 
    print("best_accuracy :", best_accuracy)



batch_size = 64
epochs = 100
# 模型训练
model_train(batch_size, epochs, train_loader, val_loader, model, optimizer, loss_function)
# Out:
# Epoch:  1 train_Loss: 1.60991414 train_Accuracy:0.2009
# Epoch:  1 val_Loss:1.61001217,  validate_Acc:0.1925
# Epoch:  2 train_Loss: 1.60968314 train_Accuracy:0.1976
# Epoch:  2 val_Loss:1.60981447,  validate_Acc:0.1930
# Epoch:  3 train_Loss: 1.60931651 train_Accuracy:0.1962
# Epoch:  3 val_Loss:1.60901700,  validate_Acc:0.2051
# Epoch:  4 train_Loss: 1.60769504 train_Accuracy:0.2178
# Epoch:  4 val_Loss:1.60798837,  validate_Acc:0.1915
# Epoch:  5 train_Loss: 1.57917931 train_Accuracy:0.2883
# Epoch:  5 val_Loss:1.43919902,  validate_Acc:0.4536
# Epoch:  6 train_Loss: 1.13893815 train_Accuracy:0.5008
# Epoch:  6 val_Loss:0.88490132,  validate_Acc:0.5716
# Epoch:  7 train_Loss: 0.81151146 train_Accuracy:0.5950
# Epoch:  7 val_Loss:0.73962631,  validate_Acc:0.6053
# Epoch:  8 train_Loss: 0.71626488 train_Accuracy:0.6325
# Epoch:  8 val_Loss:0.67654522,  validate_Acc:0.6527
# Epoch:  9 train_Loss: 0.68436083 train_Accuracy:0.6382
# Epoch:  9 val_Loss:0.66753273,  validate_Acc:0.6905
# Epoch: 10 train_Loss: 0.65746806 train_Accuracy:0.6665
# Epoch: 10 val_Loss:0.78346839,  validate_Acc:0.5801
# Epoch: 11 train_Loss: 0.67005804 train_Accuracy:0.6586
# Epoch: 11 val_Loss:0.63237106,  validate_Acc:0.6648
# Epoch: 12 train_Loss: 0.63722845 train_Accuracy:0.6941
# Epoch: 12 val_Loss:0.69522000,  validate_Acc:0.6719
# Epoch: 13 train_Loss: 0.62632662 train_Accuracy:0.6952
# Epoch: 13 val_Loss:0.61775387,  validate_Acc:0.7298
# Epoch: 14 train_Loss: 0.62632856 train_Accuracy:0.6920
# Epoch: 14 val_Loss:0.60737724,  validate_Acc:0.7480
# Epoch: 15 train_Loss: 0.60330319 train_Accuracy:0.7102
# Epoch: 15 val_Loss:0.63964879,  validate_Acc:0.6809
# Epoch: 16 train_Loss: 0.60440837 train_Accuracy:0.7152
# Epoch: 16 val_Loss:0.63500200,  validate_Acc:0.7061
# Epoch: 17 train_Loss: 0.60871157 train_Accuracy:0.7193
# Epoch: 17 val_Loss:0.59577792,  validate_Acc:0.7329
# Epoch: 18 train_Loss: 0.59475639 train_Accuracy:0.7238
# Epoch: 18 val_Loss:0.58572181,  validate_Acc:0.6996
# Epoch: 19 train_Loss: 0.58026174 train_Accuracy:0.7323
# Epoch: 19 val_Loss:0.56025733,  validate_Acc:0.7636
# Epoch: 20 train_Loss: 0.57354423 train_Accuracy:0.7409
# Epoch: 20 val_Loss:0.66961344,  validate_Acc:0.7087
# Epoch: 21 train_Loss: 0.57271817 train_Accuracy:0.7459
# Epoch: 21 val_Loss:0.55351942,  validate_Acc:0.7717
# Epoch: 22 train_Loss: 0.54861911 train_Accuracy:0.7570
# Epoch: 22 val_Loss:0.55696165,  validate_Acc:0.7087
# Epoch: 23 train_Loss: 0.53656429 train_Accuracy:0.7577
# Epoch: 23 val_Loss:0.58585729,  validate_Acc:0.7354
# Epoch: 24 train_Loss: 0.55989381 train_Accuracy:0.7448
# Epoch: 24 val_Loss:0.55413854,  validate_Acc:0.7238
# Epoch: 25 train_Loss: 0.52553638 train_Accuracy:0.7646
# Epoch: 25 val_Loss:0.55515067,  validate_Acc:0.7646
# Epoch: 26 train_Loss: 0.51100063 train_Accuracy:0.7735
# Epoch: 26 val_Loss:0.52483759,  validate_Acc:0.7576
# Epoch: 27 train_Loss: 0.53432861 train_Accuracy:0.7683
# Epoch: 27 val_Loss:0.53371190,  validate_Acc:0.7838
# Epoch: 28 train_Loss: 0.49180923 train_Accuracy:0.7848
# Epoch: 28 val_Loss:0.51846264,  validate_Acc:0.7359
# Epoch: 29 train_Loss: 0.49047065 train_Accuracy:0.7807
# Epoch: 29 val_Loss:0.49826900,  validate_Acc:0.7692
# Epoch: 30 train_Loss: 0.48076169 train_Accuracy:0.7897
# Epoch: 30 val_Loss:0.47715424,  validate_Acc:0.8105
# Epoch: 31 train_Loss: 0.46940724 train_Accuracy:0.7990
# Epoch: 31 val_Loss:0.46807339,  validate_Acc:0.8180
# Epoch: 32 train_Loss: 0.45724399 train_Accuracy:0.8018
# Epoch: 32 val_Loss:0.47026403,  validate_Acc:0.8160
# Epoch: 33 train_Loss: 0.46471805 train_Accuracy:0.7952
# Epoch: 33 val_Loss:0.54896731,  validate_Acc:0.7520
# Epoch: 34 train_Loss: 0.44016160 train_Accuracy:0.8112
# Epoch: 34 val_Loss:0.44831720,  validate_Acc:0.8231
# Epoch: 35 train_Loss: 0.45179000 train_Accuracy:0.8043
# Epoch: 35 val_Loss:0.44829345,  validate_Acc:0.8241
# Epoch: 36 train_Loss: 0.42499349 train_Accuracy:0.8183
# Epoch: 36 val_Loss:0.48726506,  validate_Acc:0.8075
# Epoch: 37 train_Loss: 0.42509293 train_Accuracy:0.8174
# Epoch: 37 val_Loss:0.43113035,  validate_Acc:0.8342
# Epoch: 38 train_Loss: 0.40938278 train_Accuracy:0.8225
# Epoch: 38 val_Loss:0.42591696,  validate_Acc:0.8256
# Epoch: 39 train_Loss: 0.41607433 train_Accuracy:0.8231
# Epoch: 39 val_Loss:0.41830921,  validate_Acc:0.8427
# Epoch: 40 train_Loss: 0.40238877 train_Accuracy:0.8250
# Epoch: 40 val_Loss:0.40428152,  validate_Acc:0.8493
# Epoch: 41 train_Loss: 0.42239600 train_Accuracy:0.8169
# Epoch: 41 val_Loss:0.40237898,  validate_Acc:0.8392
# Epoch: 42 train_Loss: 0.40193794 train_Accuracy:0.8245
# Epoch: 42 val_Loss:0.43352999,  validate_Acc:0.8115
# Epoch: 43 train_Loss: 0.38898131 train_Accuracy:0.8364
# Epoch: 43 val_Loss:0.39363929,  validate_Acc:0.8362
# Epoch: 44 train_Loss: 0.36916808 train_Accuracy:0.8477
# Epoch: 44 val_Loss:0.37440358,  validate_Acc:0.8503
# Epoch: 45 train_Loss: 0.38219816 train_Accuracy:0.8423
# Epoch: 45 val_Loss:0.44649863,  validate_Acc:0.8226
# Epoch: 46 train_Loss: 0.37414102 train_Accuracy:0.8450
# Epoch: 46 val_Loss:0.41883374,  validate_Acc:0.8367
# Epoch: 47 train_Loss: 0.36192038 train_Accuracy:0.8483
# Epoch: 47 val_Loss:0.39414496,  validate_Acc:0.8548
# Epoch: 48 train_Loss: 0.36951134 train_Accuracy:0.8433
# Epoch: 48 val_Loss:0.40655621,  validate_Acc:0.8236
# Epoch: 49 train_Loss: 0.35114318 train_Accuracy:0.8528
# Epoch: 49 val_Loss:0.36616089,  validate_Acc:0.8574
# Epoch: 50 train_Loss: 0.34572323 train_Accuracy:0.8553
# Epoch: 50 val_Loss:0.35725673,  validate_Acc:0.8659
# Epoch: 51 train_Loss: 0.33556001 train_Accuracy:0.8601
# Epoch: 51 val_Loss:0.34189501,  validate_Acc:0.8604
# Epoch: 52 train_Loss: 0.34051252 train_Accuracy:0.8574
# Epoch: 52 val_Loss:0.39704622,  validate_Acc:0.8417
# Epoch: 53 train_Loss: 0.34573924 train_Accuracy:0.8543
# Epoch: 53 val_Loss:0.40561927,  validate_Acc:0.8417
# Epoch: 54 train_Loss: 0.33689786 train_Accuracy:0.8584
# Epoch: 54 val_Loss:0.45677599,  validate_Acc:0.8125
# Epoch: 55 train_Loss: 0.34963740 train_Accuracy:0.8525
# Epoch: 55 val_Loss:0.34675701,  validate_Acc:0.8614
# Epoch: 56 train_Loss: 0.32652132 train_Accuracy:0.8646
# Epoch: 56 val_Loss:0.32427710,  validate_Acc:0.8684
# Epoch: 57 train_Loss: 0.32099586 train_Accuracy:0.8678
# Epoch: 57 val_Loss:0.35712435,  validate_Acc:0.8589
# Epoch: 58 train_Loss: 0.32098651 train_Accuracy:0.8684
# Epoch: 58 val_Loss:0.34822079,  validate_Acc:0.8730
# Epoch: 59 train_Loss: 0.32252084 train_Accuracy:0.8636
# Epoch: 59 val_Loss:0.33863595,  validate_Acc:0.8725
# Epoch: 60 train_Loss: 0.31787444 train_Accuracy:0.8666
# Epoch: 60 val_Loss:0.31397018,  validate_Acc:0.8780
# Epoch: 61 train_Loss: 0.33358679 train_Accuracy:0.8670
# Epoch: 61 val_Loss:0.41863295,  validate_Acc:0.8291
# Epoch: 62 train_Loss: 0.32022071 train_Accuracy:0.8656
# Epoch: 62 val_Loss:0.35624942,  validate_Acc:0.8548
# Epoch: 63 train_Loss: 0.30865051 train_Accuracy:0.8704
# Epoch: 63 val_Loss:0.31178624,  validate_Acc:0.8785
# Epoch: 64 train_Loss: 0.32563970 train_Accuracy:0.8699
# Epoch: 64 val_Loss:0.30826994,  validate_Acc:0.8816
# Epoch: 65 train_Loss: 0.30255120 train_Accuracy:0.8784
# Epoch: 65 val_Loss:0.30405445,  validate_Acc:0.8841
# Epoch: 66 train_Loss: 0.30063776 train_Accuracy:0.8801
# Epoch: 66 val_Loss:0.30571857,  validate_Acc:0.8790
# Epoch: 67 train_Loss: 0.29478736 train_Accuracy:0.8771
# Epoch: 67 val_Loss:0.34496114,  validate_Acc:0.8569
# Epoch: 68 train_Loss: 0.30434288 train_Accuracy:0.8794
# Epoch: 68 val_Loss:0.29782999,  validate_Acc:0.8871
# Epoch: 69 train_Loss: 0.29330835 train_Accuracy:0.8823
# Epoch: 69 val_Loss:0.30402148,  validate_Acc:0.8856
# Epoch: 70 train_Loss: 0.30139689 train_Accuracy:0.8768
# Epoch: 70 val_Loss:0.29921054,  validate_Acc:0.8861
# Epoch: 71 train_Loss: 0.28635883 train_Accuracy:0.8836
# Epoch: 71 val_Loss:0.33756644,  validate_Acc:0.8599
# Epoch: 72 train_Loss: 0.28991514 train_Accuracy:0.8819
# Epoch: 72 val_Loss:0.28026286,  validate_Acc:0.8952
# Epoch: 73 train_Loss: 0.33320405 train_Accuracy:0.8644
# Epoch: 73 val_Loss:0.28090078,  validate_Acc:0.8952
# Epoch: 74 train_Loss: 0.28207861 train_Accuracy:0.8823
# Epoch: 74 val_Loss:0.30269816,  validate_Acc:0.8816
# Epoch: 75 train_Loss: 0.31078450 train_Accuracy:0.8727
# Epoch: 75 val_Loss:0.27937412,  validate_Acc:0.8962
# Epoch: 76 train_Loss: 0.28197758 train_Accuracy:0.8887
# Epoch: 76 val_Loss:0.27863708,  validate_Acc:0.8967
# Epoch: 77 train_Loss: 0.27578270 train_Accuracy:0.8865
# Epoch: 77 val_Loss:0.28899766,  validate_Acc:0.8921
# Epoch: 78 train_Loss: 0.27115613 train_Accuracy:0.8903
# Epoch: 78 val_Loss:0.28353395,  validate_Acc:0.8906
# Epoch: 79 train_Loss: 0.26813010 train_Accuracy:0.8918
# Epoch: 79 val_Loss:0.27500429,  validate_Acc:0.8962
# Epoch: 80 train_Loss: 0.26222735 train_Accuracy:0.8950
# Epoch: 80 val_Loss:0.27380417,  validate_Acc:0.8992
# Epoch: 81 train_Loss: 0.27189896 train_Accuracy:0.8905
# Epoch: 81 val_Loss:0.29320311,  validate_Acc:0.8866
# Epoch: 82 train_Loss: 0.26385954 train_Accuracy:0.8947
# Epoch: 82 val_Loss:0.26595028,  validate_Acc:0.8967
# Epoch: 83 train_Loss: 0.27400638 train_Accuracy:0.8889
# Epoch: 83 val_Loss:0.27206795,  validate_Acc:0.8972
# Epoch: 84 train_Loss: 0.26721021 train_Accuracy:0.8941
# Epoch: 84 val_Loss:0.32531633,  validate_Acc:0.8664
# Epoch: 85 train_Loss: 0.26373332 train_Accuracy:0.8932
# Epoch: 85 val_Loss:0.26337820,  validate_Acc:0.9052
# Epoch: 86 train_Loss: 0.25053385 train_Accuracy:0.9023
# Epoch: 86 val_Loss:0.30079488,  validate_Acc:0.8790
# Epoch: 87 train_Loss: 0.25977305 train_Accuracy:0.8974
# Epoch: 87 val_Loss:0.26907771,  validate_Acc:0.8916
# Epoch: 88 train_Loss: 0.25461783 train_Accuracy:0.8992
# Epoch: 88 val_Loss:0.26689134,  validate_Acc:0.8962
# Epoch: 89 train_Loss: 0.26105438 train_Accuracy:0.8960
# Epoch: 89 val_Loss:0.30810081,  validate_Acc:0.8841
# Epoch: 90 train_Loss: 0.26150652 train_Accuracy:0.8933
# Epoch: 90 val_Loss:0.24649659,  validate_Acc:0.9088
# Epoch: 91 train_Loss: 0.25684851 train_Accuracy:0.8965
# Epoch: 91 val_Loss:0.24473594,  validate_Acc:0.9093
# Epoch: 92 train_Loss: 0.24805584 train_Accuracy:0.9050
# Epoch: 92 val_Loss:0.26811578,  validate_Acc:0.8957
# Epoch: 93 train_Loss: 0.24598284 train_Accuracy:0.9044
# Epoch: 93 val_Loss:0.27614686,  validate_Acc:0.8896
# Epoch: 94 train_Loss: 0.24065550 train_Accuracy:0.9065
# Epoch: 94 val_Loss:0.24951310,  validate_Acc:0.9062
# Epoch: 95 train_Loss: 0.24705696 train_Accuracy:0.9019
# Epoch: 95 val_Loss:0.24482703,  validate_Acc:0.9088
# Epoch: 96 train_Loss: 0.23176345 train_Accuracy:0.9089
# Epoch: 96 val_Loss:0.25478611,  validate_Acc:0.9103
# Epoch: 97 train_Loss: 0.23908406 train_Accuracy:0.9054
# Epoch: 97 val_Loss:0.23745721,  validate_Acc:0.9083
# Epoch: 98 train_Loss: 0.25456658 train_Accuracy:0.8984
# Epoch: 98 val_Loss:0.22416047,  validate_Acc:0.9173
# Epoch: 99 train_Loss: 0.22968642 train_Accuracy:0.9089
# Epoch: 99 val_Loss:0.22397658,  validate_Acc:0.9183
# Epoch: 100 train_Loss: 0.22839177 train_Accuracy:0.9117
# Epoch: 100 val_Loss:0.25998522,  validate_Acc:0.9037
#
# Duration: 583 seconds
# best_accuracy : 0.9183467741935484

# %%
from sklearn.metrics import confusion_matrix 
import torch.nn.functional as F
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # 有GPU先用GPU训练

# 模型 测试集 验证  

# 得出每一类的分类准确率
model = torch.load('best_model_cnn2d.pt')
model = model.to(device)

# 使用测试集数据进行推断并计算每一类的分类准确率
class_labels = []  # 存储类别标签
predicted_labels = []  # 存储预测的标签

with torch.no_grad():
    for test_data, test_label in test_loader:
        # 将模型设置为评估模式
        model.eval()
        test_data = test_data.to(device)
        test_output = model(test_data)
        probabilities = F.softmax(test_output, dim=1)
        predicted = torch.argmax(probabilities, dim=1)
        
        class_labels.extend(test_label.tolist())
        predicted_labels.extend(predicted.tolist())

# 混淆矩阵
confusion_mat = confusion_matrix(class_labels, predicted_labels)

from sklearn.metrics import classification_report
# 计算每一类的分类准确率
report = classification_report(class_labels, predicted_labels, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9951    1.0000    0.9975       203
#            1     0.8150    0.8763    0.8446       186
#            2     0.7890    0.9101    0.8452       189
#            3     0.9392    0.7473    0.8323       186
#            4     0.9105    0.8827    0.8964       196
#
#     accuracy                         0.8854       960
#    macro avg     0.8898    0.8833    0.8832       960
# weighted avg     0.8915    0.8854    0.8852       960

# %%
# 绘制混淆矩阵
import matplotlib.pyplot as plt
import seaborn as sns
# 原始标签和自定义标签的映射
label_mapping = {
    0: "C1",1: "C2",2: "C3",3: "C4",4: "C5",
}

# 绘制混淆矩阵
plt.figure(figsize=(5, 4), dpi=300)
sns.heatmap(confusion_mat,  xticklabels=label_mapping.values(), yticklabels=label_mapping.values(),annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix of 2DCNN-load')
plt.savefig("cnn2d_confusion.png")
plt.show()
